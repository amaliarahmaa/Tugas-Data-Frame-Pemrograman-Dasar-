# %%
import pandas as pd 

tgs_excel = pd.read_excel('datasampah.xlsx', sheet_name='data')
tgs_excel
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 238  239             32    JAWA BARAT                 3275
# 239  240             32    JAWA BARAT                 3276
# 240  241             32    JAWA BARAT                 3277
# 241  242             32    JAWA BARAT                 3278
# 242  243             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_produksi_sampah        satuan  tahun
# 0       KABUPATEN BOGOR                 1511.15  TON PER HARI   2015
# 1    KABUPATEN SUKABUMI                  419.01  TON PER HARI   2015
# ...

# %%
# Soal 1

df_produksi_sampah = tgs_excel[['nama_kabupaten_kota', 'jumlah_produksi_sampah', 'tahun']]
print(df_produksi_sampah)
# Out:
#     nama_kabupaten_kota  jumlah_produksi_sampah  tahun
# 0       KABUPATEN BOGOR                 1511.15   2015
# 1    KABUPATEN SUKABUMI                  419.01   2015
# 2     KABUPATEN CIANJUR                  981.41   2015
# 3     KABUPATEN BANDUNG                 1895.94   2015
# 4       KABUPATEN GARUT                  464.74   2015
# ..                  ...                     ...    ...
# 238         KOTA BEKASI                     NaN   2023
# 239          KOTA DEPOK                     NaN   2023
# 240         KOTA CIMAHI                     NaN   2023
# 241    KOTA TASIKMALAYA                     NaN   2023
# 242         KOTA BANJAR                     NaN   2023
#
# [243 rows x 3 columns]

# %%
# Soal 2

total_produksi_sampah = 0
tahun_produksi = int(input("masukkan tahun berapa yang ingin di cek total produksi sampah"))

while (tahun_produksi < 2015 or tahun_produksi > 2023):
    tahun_produksi = int(input("masukkan tahunnya untuk cek produksi sampah diantara tahun 2015 sampai 2023"))

for index, baris in df_produksi_sampah.iterrows():
    if baris['tahun'] == tahun_produksi:
        jumlah_produksi_sampah = total_produksi_sampah + baris['jumlah_produksi_sampah']
        total_produksi_sampah = jumlah_produksi_sampah

print (f"jumlah sampah berdasarkan tahun yang anda cek adalah : {total_produksi_sampah} ton")
# Out:
# jumlah sampah berdasarkan tahun yang anda cek adalah : 20969.269999999997 ton

# %%
# Soal 3

data_tahun = {}

for index, baris in df_produksi_sampah.iterrows():
    data_tahun[baris['tahun']] = 0

for i in data_tahun.keys():
    for index, baris in df_produksi_sampah.iterrows():
        if baris['tahun'] == int(i):
            data_tahun[i] = data_tahun[i] + baris['jumlah_produksi_sampah']

for i, j in data_tahun.items():
    print(f"tahun {i} : jumlah sampah per ton nya yaitu {j}")
# Out:
# tahun 2015 : jumlah sampah per ton nya yaitu 20969.269999999997
# tahun 2016 : jumlah sampah per ton nya yaitu 20969.269999999997
# tahun 2017 : jumlah sampah per ton nya yaitu 20969.269999999997
# tahun 2018 : jumlah sampah per ton nya yaitu 22772.92
# tahun 2019 : jumlah sampah per ton nya yaitu 24490.559999999998
# tahun 2020 : jumlah sampah per ton nya yaitu 25333.0
# tahun 2021 : jumlah sampah per ton nya yaitu 15735.360000000002
# tahun 2022 : jumlah sampah per ton nya yaitu nan
# tahun 2023 : jumlah sampah per ton nya yaitu nan

# %%
# soal 4
data_kota_kab = {}
for index, baris in df_produksi_sampah.iterrows():

    if baris['tahun'] not in data_kota_kab:
        data_kota_kab[baris['tahun']] = {}

    if baris['nama_kabupaten_kota'] not in data_kota_kab[baris['tahun']]:
        data_kota_kab[baris['tahun']][baris['nama_kabupaten_kota']] = 0
    

    data_kota_kab[baris['tahun']][baris['nama_kabupaten_kota']] += baris['jumlah_produksi_sampah']

for i, j in data_kota_kab.items():
    for a, b in j.items():
        print(f"untuk tahun {i}, dari kota/kab {a}, jumlah sampah per ton yaitu {b}")
# Out:
# untuk tahun 2015, dari kota/kab KABUPATEN BOGOR, jumlah sampah per ton yaitu 1511.15
# untuk tahun 2015, dari kota/kab KABUPATEN SUKABUMI, jumlah sampah per ton yaitu 419.01
# untuk tahun 2015, dari kota/kab KABUPATEN CIANJUR, jumlah sampah per ton yaitu 981.41
# untuk tahun 2015, dari kota/kab KABUPATEN BANDUNG, jumlah sampah per ton yaitu 1895.94
# untuk tahun 2015, dari kota/kab KABUPATEN GARUT, jumlah sampah per ton yaitu 464.74
# untuk tahun 2015, dari kota/kab KABUPATEN TASIKMALAYA, jumlah sampah per ton yaitu 464.52
# untuk tahun 2015, dari kota/kab KABUPATEN CIAMIS, jumlah sampah per ton yaitu 260.91
# untuk tahun 2015, dari kota/kab KABUPATEN KUNINGAN, jumlah sampah per ton yaitu 251.7
# untuk tahun 2015, dari kota/kab KABUPATEN CIREBON, jumlah sampah per ton yaitu 465.75
# untuk tahun 2015, dari kota/kab KABUPATEN MAJALENGKA, jumlah sampah per ton yaitu 254.63
# untuk tahun 2015, dari kota/kab KABUPATEN SUMEDANG, jumlah sampah per ton yaitu 237.96
# ...

# %%
# Export excel

df_produksi_sampah.to_excel('tugas_dataframe.xlsx', index= False)

# %%
# Export csv

df_produksi_sampah.to_csv('tugas_dataframe.csv', index= False)
